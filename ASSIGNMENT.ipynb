# %% [markdown]
# <a href="https://colab.research.google.com/github/Babitha-23/Assignment/blob/main/ASSIGNMENT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#assignment1

x=[1,2,3,4,5]
y=[0,2,4,6,8]

plt.plot(x,y,color='purple',linestyle=':',markersize='12')
plt.title('The first assignment')

plt.xlabel('x axis')
plt.ylabel('y axis')

plt.figure(figsize=(5,4))
plt.savefig('myplot.png', dpi=600)

plt.plot(x, label="test1",color='black')
plt.plot(y, label="test2",color='red')
plt.plot()

plt.legend()
plt.savefig('mygraph.png', dpi=300,edgecolor='b',
        orientation='portrait')

plt.show()
